# %%
import xml.etree.ElementTree as ET
tree = ET.parse('tripinfo.xml')

# %%
root = tree.getroot()

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['tripinfos',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
#  'tripinfo',
# ...

# %%
time = 0
for vehicle in root.iter('tripinfo'):
#     print(vehicle.attrib['timeLoss'])
    time += float(vehicle.attrib['timeLoss'])**2

# %%
time
# Out:
# 100118438.82270017

# %%
100118438.82270017/30
# Out:
# 3337281.2940900056

# %%
phases = []
phases.insert(0, [])
phases.insert(1, [9, 10])  # phase Left. Westbound
phases.insert(2, [16, 17, 18, 19])  # phase Through, Right. Eastbound
phases.insert(3, [15])  # phase Left. Northbound
phases.insert(4, [0, 1, 2, 3])  # phase Through, Right. Southbound
phases.insert(5, [20, 21])  # phase Left. Eastbound
phases.insert(6, [5, 6, 7, 8])  # phase Through, Right. Westbound
phases.insert(7, [4])  # phase Left. Southbound
phases.insert(8, [11, 12, 13, 14])  # phase Through, Right. Northbound

# %%
phases
# Out:
# [[],
#  [9, 10],
#  [16, 17, 18, 19],
#  [15],
#  [0, 1, 2, 3],
#  [20, 21],
#  [5, 6, 7, 8],
#  [4],
#  [11, 12, 13, 14]]

# %%
current_phases = [2,6]
lanes = []
for lad in current_phases:
    lanes += phases[lad]

# %%
lanes
# Out:
# [16, 17, 18, 19, 5, 6, 7, 8]

# %%
through_table = [6, 2, 8, 4]

# %%
opposite = []
for i in through_table:
    if i not in current_phases:
        opposite.append(i)

# %%
opposite
# Out:
# [8, 4]

# %%
ns_dir, ne_dir = {'left': [1, 5], 'through': [6, 2]},{'left': [3, 7], 'through': [4, 8]}

# %%
2 in ns_dir['through']
# Out:
# True

# %%
ns_dir['left']
# Out:
# [1, 5]

# %%
cur = ['left','through']

# %%
for i,j in ns_dir.values():
    print(i,j)
# Out:
# 1 5
# 6 2

# %%
len(['left', 'through'])
# Out:
# 2

# %%
ha = {0:'ec', 1:'ha'}

# %%
ha[0]
# Out:
# 'ec'

# %%
A={0:'S0',1:'S1',2:'S2',3:'S3',4:'S4',5:'W0',7:'W1',8:'W2',9:'W3',10:'W4',11:'N0',12:'N1',13:'N2',14:'N3',15:'N4',16:'E0',18:'E1',19:'E2',20:'E3',21:'E4'}

# %%
A[6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-4d4ae53b251b> in <module>()
# ----> 1 A[6]
#
# KeyError: 6
